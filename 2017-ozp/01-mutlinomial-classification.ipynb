# %% [markdown]
# Funkcija softmax

# %%
import numpy as np

def softmax(z):
    v = np.exp(z)
    return v/np.sum(v)

# %%
z = [4.2, 2.1, 3]
v = np.exp(z)
v / np.sum(v)
# Out:
# array([ 0.70241952,  0.08601579,  0.21156469])
